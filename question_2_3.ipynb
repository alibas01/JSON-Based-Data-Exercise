# %% [markdown]
# # Qestion 2

# %%
import numpy as np
import pandas as pd
import json
json_file_path='data/world_bank_projects.json'
with open(json_file_path,'r') as json_file:
    json_data=json.load(json_file)
json_df=pd.DataFrame(json_data)
json_project_df=json_df.mjtheme_namecode
list_project=json_project_df.tolist()
project_name=[item for sublist in list_project for item in sublist]
project_name_df=pd.DataFrame(project_name)

# %%
project_name_df.name.value_counts().head(10)
# Out:
# Environment and natural resources management    223
# Rural development                               202
# Human development                               197
# Public sector governance                        184
# Social protection and risk management           158
# Financial and private sector development        130
#                                                 122
# Social dev/gender/inclusion                     119
# Trade and integration                            72
# Urban development                                47
# Name: name, dtype: int64

# %% [markdown]
# # Question 3

# %%
project_name_df_empty=project_name_df[project_name_df.name=='']

# %%
project_name_df_empty.code.value_counts()
# Out:
# 11    27
# 4     16
# 2     15
# 10    14
# 8     13
# 7     11
# 6     10
# 5      5
# 1      5
# 9      3
# 3      3
# Name: code, dtype: int64

# %%
dict_projects={'1':'Economic management','2':'Public sector governance','3':'Rule of law','4':'Financial and private sector development',
               '5':'Trade and integration','6':'Social protection and risk management','7':'Social dev/gender/inclusion',
               '8':'Human development','9':'Urban development','10':'Rural development',
               '11':'Environment and natural resources management'}

# %%
project_name = project_name_df.applymap(lambda x: np.nan if x == '' else x)

# %%
project_name.head()
# Out:
#   code                                   name
# 0    8                      Human development
# 1   11                                    NaN
# 2    1                    Economic management
# 3    6  Social protection and risk management
# 4    5                  Trade and integration

# %%
project_name.ffill()
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11                             Human development
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6         Social protection and risk management
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# ...

# %%
project_name_df=pd.DataFrame(project_name)
